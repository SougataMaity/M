# %% [markdown]
# Q.1 In the sense of machine learning, what is a model? What is the best way to train a model?
#
# In machine learning model is a process to recognize the patterns understand the hidden informations.

# %% [markdown]
# Q.2 In the sense of machine learning, explain the &quot;No Free Lunch&quot; theorem.
#
# The no free lunch theorem for supervised machine is a theorem that essentially inplies that no single machine learning algorithm is universally the best performing algorithm for all problems.

# %% [markdown]
# Q.3 Describe the K-fold cross-validation mechanism in detail.
#
# k-fold cross validation is where split dataset into k number of series or folds .Where (k-1) folds use for training and one is use for testing.
#
# Suppose we take k=5
# ![1_IjKy-Zc9zVOHFzMw2GXaQw.png](attachment:1_IjKy-Zc9zVOHFzMw2GXaQw.png)

# %% [markdown]
# Q.4 Describe the bootstrap sampling method. What is the aim of it?
#
# Bootstrap Sampling is a method that involves drawing of sample data repeatedly with replacement from a data source or original dataset.
# Estimate the population parameters.

# %% [markdown]
# Q.5 What is the significance of calculating the Kappa value for a classification model? Demonstrate how to measure the Kappa value of a classification model using a sample collection of results.
#
# kappa basically tells you how much better your classifier is performing over the performance of a classifier that simply guesses at random according to the frequency of each class. Cohen's kappa is always less than or equal to 1. Values of 0 or less,

# %% [markdown]
# Q.6. Describe the model ensemble method. In machine learning, what part does it play?
#
# Ensemble modeling is a process where multiple diverse models are created to predict an outcome, either by using many different modeling algorithms or using different training data sets.
# It use for the better and more accurate of a classification model.

# %% [markdown]
# 7. What is a descriptive model&#39;s main purpose? Give examples of real-world problems that descriptive models were used to solve.
#
# Descriptive modeling is a mathematical process that describes real-world events and the relationships between factors responsible for them.
#
# The process is used by consumer-driven organizations to help them target their marketing and advertising efforts.

# %% [markdown]
# Q.8 Describe how to evaluate a linear regression model.
#
# Suppose we have a data set where one feature(x) and one output attribute(y) and they are correlated each others. Our aim is to constract a linear regression model also estimate the parameters.
#
# y = a + bx + e where e imply the error and e~ N(0, sigma<sup>2</sup>)
# a is a intercept and b is a coefficent, our aim is to estimate a and b
#
# y = a + bx + e<br>
# mean(y) = a + b*mean(x)<br>
# a = mean(y) - b * mean(x) <br>
# cov(x,y) = b*var(x)<br>
# b = cov(x,y)/var(x)

# %% [markdown]
# Q.9 Distinguish
#
# Descriptive vs. predictive models
# - Descriptive : Descriptive modeling is a mathematical process that describes real-world events and the relationships between factors responsible for them.
# - Predictive : Predictive modeling is a commonly used statistical technique to predict future behavior.
#
#
# Underfitting vs. overfitting the model
# - Underfitting : Underfitting is a scenario in data science where a data model is unable to capture the relationship between the input and output variables accurately,
# - Overfitting : Overfitting is a concept in data science, which occurs when a statistical model fits exactly against its training data.
#
# Mainly Underitting imply low variance and high bias and Ovrfitting high variance and high bias.
#
# Bootstrapping vs. cross-validation
# - Bootstrapping:Bootstrapping method uses the original dataset to create multiple datasets after resampling with replacement.
# - Cross-validating:Cross validation splits the available dataset to create multiple datasets

# %% [markdown]
# Q.10 Short and quick note
#
# 1. LOOCV : Leave One out cross validation where just a single observation is held out for validation.
#
# Suppose we create k-fold of a dataset, then each fold one random value for testing and remaning value for the training.
#
#
# 2. F-measurement : Test of accuracy of binary classification for
#
# F scrore or measurement  = hermonic mean of precesion and recall
#
# 3. The width of the silhouette : Silhouette Coefficient or silhouette score is a metric used to calculate the goodness of a clustering technique
#
# Its value ranges from -1 to 1.
#
# 4. Receiver operating characteristic curve : A receiver operating characteristic curve, or ROC curve, is a graphical plot that illustrates the diagnostic ability of a binary classifier system as its discrimination threshold is varied.
